# %%
import pandas as pd

# %%
from pandas import read_excel


weather = read_excel('/Users/rishireddy/Desktop/BFOR 516/Datasets for ML Model/DFW Weather.xlsx')

# %%
weather['year'] = pd.DatetimeIndex(weather['Date']).year

# %%
weather['month'] = pd.DatetimeIndex(weather['Date']).month

# %%
weather.head()
# Out:
#         Date  Max Temp  Min Temp  Avg Temp  Departure from Normal  HDD  CDD  \
# 0 2016-01-01        49        39      44.0                   -1.8   21    0
# 1 2016-01-02        51        38      44.5                   -1.3   20    0
# 2 2016-01-03        60        37      48.5                    2.8   16    0
# 3 2016-01-04        54        32      43.0                   -2.7   22    0
# 4 2016-01-05        47        32      39.5                   -6.2   25    0
#
#    Precipitation  New Snow  Snow Depth  year  month
# 0            0.0       0.0         0.0  2016      1
# 1            0.0       0.0         0.0  2016      1
# 2            0.0       0.0         0.0  2016      1
# 3            0.0       0.0         0.0  2016      1
# 4            0.0       0.0         0.0  2016      1

# %%
import numpy as np

# %%
weather.describe()
# Out:
#           Max Temp     Min Temp     Avg Temp  Departure from Normal  \
# count  2192.000000  2192.000000  2192.000000            2192.000000
# mean     78.020073    57.814781    67.917427               1.276551
# std      15.944351    15.875468    15.541791               7.668661
# min      14.000000    -2.000000     8.000000             -42.700000
# 25%      67.000000    45.000000    56.000000              -2.925000
# 50%      80.000000    59.000000    70.000000               1.400000
# 75%      92.000000    73.000000    82.000000               5.600000
# max     109.000000    86.000000    95.500000              28.100000
#
#                HDD          CDD  Precipitation     New Snow   Snow Depth  \
# count  2192.000000  2192.000000    2192.000000  2192.000000  2192.000000
# mean      5.203923     8.375912       0.109448     0.002419     0.008212
# std       8.503760     9.050400       0.381863     0.088182     0.165279
# ...

# %%
WeatherStats = weather.groupby(['year', 'month']).mean()

# %%
WeatherStats2 = weather.groupby(['year', 'month']).sum()

# %%
WeatherStats2.head()
# Out:
#             Max Temp  Min Temp  Avg Temp  Departure from Normal  HDD  CDD  \
# year month
# 2016 1          1781      1133    1457.0                   21.7  550    0
#      2          1939      1260    1599.5                  131.9  290   11
#      3          2216      1577    1896.5                   92.3  142   30
#      4          2346      1742    2044.0                   74.5   27  131
#      5          2526      1969    2247.5                  -48.2   12  251
#
#             Precipitation  New Snow  Snow Depth
# year month
# 2016 1             1.0401       0.0         0.0
#      2             2.2003       0.0         0.0
#      3             2.6702       0.0         0.0
#      4             4.6004       0.0         0.0
#      5             6.2503       0.0         0.0

# %%
WeatherStats.to_excel('/Users/rishireddy/Desktop/BFOR 516/Datasets for ML Model/Weatherdata.xlsx')

# TEST.to_csv('/Users/rishireddy/Desktop/BFOR 516/Datasets for ML Model/Weatherdata.csv')

# %%
WeatherStats2.to_excel('/Users/rishireddy/Desktop/BFOR 516/Datasets for ML Model/Weatherdata2.xlsx')

# %%
weather.groupby(['year', 'month']).mean()
# Out:
#              Max Temp   Min Temp   Avg Temp  Departure from Normal        HDD  \
# year month
# 2016 1      57.451613  36.548387  47.000000               0.700000  17.741935
#      2      66.862069  43.448276  55.155172               4.548276  10.000000
#      3      71.483871  50.870968  61.177419               2.977419   4.580645
#      4      78.200000  58.066667  68.133333               2.483333   0.900000
#      5      81.483871  63.516129  72.500000              -1.554839   0.387097
# ...               ...        ...        ...                    ...        ...
# 2021 8      94.322581  75.870968  85.096774              -0.654839   0.000000
#      9      91.700000  69.233333  80.466667               1.926667   0.000000
#      10     83.161290  60.806452  71.983871               4.238710   0.483871
#      11     69.100000  46.266667  57.683333               1.283333   7.633333
#      12     72.580645  50.000000  61.290323              13.193548   5.580645
#
# ...

# %%
weather.describe()
# Out:
#           Max Temp     Min Temp     Avg Temp  Departure from Normal  \
# count  2192.000000  2192.000000  2192.000000            2192.000000
# mean     78.020073    57.814781    67.917427               1.276551
# std      15.944351    15.875468    15.541791               7.668661
# min      14.000000    -2.000000     8.000000             -42.700000
# 25%      67.000000    45.000000    56.000000              -2.925000
# 50%      80.000000    59.000000    70.000000               1.400000
# 75%      92.000000    73.000000    82.000000               5.600000
# max     109.000000    86.000000    95.500000              28.100000
#
#                HDD          CDD
# count  2192.000000  2192.000000
# mean      5.203923     8.375912
# std       8.503760     9.050400
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     5.000000
# 75%       9.000000    17.000000
# max      57.000000    31.000000

# %%
Step1. convert the column to datetime : df['Date']=pd.to_datetime(df['Date'], format='%Y-%m-%d')
Step2. extract the year or the month using DatetimeIndex() method pd.DatetimeIndex(df['ArrivalDate']).year.

# %%
weather['Date']=pd.to_datetime(weather['Date'], format='%Y-%m-%d')

# %%
weather[["day", "mm", "year"]] = weather['Date'].str.split('/', expand=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-6176675d8bc4> in <module>
# ----> 1 weather[["day", "mm", "year"]] = weather['Date'].str.split('/', expand=True)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
#     188         # Replace the property with the accessor object. Inspired by:
# ...

# %%
Year = pd.DatetimeIndex(weather['Date']).year

# %%
weather.head()
# Out:
#         Date  Max Temp  Min Temp  Avg Temp  Departure from Normal  HDD  CDD  \
# 0 2016-01-01        49        39      44.0                   -1.8   21    0
# 1 2016-01-02        51        38      44.5                   -1.3   20    0
# 2 2016-01-03        60        37      48.5                    2.8   16    0
# 3 2016-01-04        54        32      43.0                   -2.7   22    0
# 4 2016-01-05        47        32      39.5                   -6.2   25    0
#
#   Precipation New Snow Snow Depth
# 0           0        0          0
# 1           0        0          0
# 2           0        0          0
# 3           0        0          0
# 4           0        0          0
